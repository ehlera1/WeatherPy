# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Import dependencis and initialize counter and an empty list that will hold the weather data

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        weather_description = city_weather["weather"]
        city_weather_description = weather_description[0]["description"] 
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | amapa
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | marsa matruh
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | port lincoln
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | severo-kurilsk
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 1 | hadrut
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | acarau
# Processing Record 16 of Set 1 | vostok
# Processing Record 17 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | kichmengskiy gorodok
# Processing Record 20 of Set 1 | talnakh
# Processing Record 21 of Set 1 | snasa
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | provideniya
# Processing Record 24 of Set 1 | kieta
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | mazamari
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | hamilton
# Processing Record 31 of Set 1 | praia da vitoria
# Processing Record 32 of Set 1 | ahipara
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | huarmey
# Processing Record 36 of Set 1 | iqaluit
# Processing Record 37 of Set 1 | luderitz
# Processing Record 38 of Set 1 | verkhnyaya inta
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | geraldton
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | fairbanks
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | tazovskiy
# Processing Record 47 of Set 1 | ventspils
# Processing Record 48 of Set 1 | namibe
# Processing Record 49 of Set 1 | bulnes
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | cayenne
# Processing Record 4 of Set 2 | beira
# Processing Record 5 of Set 2 | meulaboh
# Processing Record 6 of Set 2 | flinders
# Processing Record 7 of Set 2 | jinchang
# Processing Record 8 of Set 2 | touros
# Processing Record 9 of Set 2 | vikravandi
# Processing Record 10 of Set 2 | north branch
# Processing Record 11 of Set 2 | cidreira
# Processing Record 12 of Set 2 | zhigansk
# Processing Record 13 of Set 2 | shimoda
# Processing Record 14 of Set 2 | inhambane
# Processing Record 15 of Set 2 | kungurtug
# Processing Record 16 of Set 2 | tarata
# Processing Record 17 of Set 2 | alekseyevka
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | jardim
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 2 | bundaberg
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | karpuninskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 | le port
# Processing Record 28 of Set 2 | palmer
# Processing Record 29 of Set 2 | saint anthony
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | sangar
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | lixourion
# Processing Record 36 of Set 2 | punta arenas
# Processing Record 37 of Set 2 | matagami
# Processing Record 38 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | bolshiye uki
# City not found. Skipping...
# Processing Record 41 of Set 2 | gikongoro
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | balakhninskiy
# Processing Record 45 of Set 2 | coihaique
# Processing Record 46 of Set 2 | bandarbeyla
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | ewa beach
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 50 of Set 2 | bandar-e anzali
# Processing Record 1 of Set 3 | hasaki
# Processing Record 2 of Set 3 | bubaque
# Processing Record 3 of Set 3 | tual
# Processing Record 4 of Set 3 | strathpeffer
# Processing Record 5 of Set 3 | kloulklubed
# Processing Record 6 of Set 3 | guerrero negro
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | mathbaria
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | jishou
# Processing Record 11 of Set 3 | saravan
# Processing Record 12 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 13 of Set 3 | faya
# Processing Record 14 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 3 | phaltan
# Processing Record 16 of Set 3 | torbay
# Processing Record 17 of Set 3 | kangaatsiaq
# Processing Record 18 of Set 3 | banyo
# Processing Record 19 of Set 3 | algiers
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | henties bay
# Processing Record 22 of Set 3 | north platte
# Processing Record 23 of Set 3 | katsuura
# Processing Record 24 of Set 3 | komsomolskiy
# Processing Record 25 of Set 3 | fortuna
# Processing Record 26 of Set 3 | bulgan
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | katobu
# Processing Record 29 of Set 3 | osakarovka
# Processing Record 30 of Set 3 | sao jose da coroa grande
# Processing Record 31 of Set 3 | aykhal
# Processing Record 32 of Set 3 | muzhi
# Processing Record 33 of Set 3 | panguipulli
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | garowe
# Processing Record 36 of Set 3 | saint-augustin
# Processing Record 37 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 3 | te anau
# Processing Record 39 of Set 3 | port macquarie
# Processing Record 40 of Set 3 | litoral del san juan
# City not found. Skipping...
# Processing Record 41 of Set 3 | tefe
# Processing Record 42 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 3 | georgetown
# Processing Record 44 of Set 3 | aksarka
# Processing Record 45 of Set 3 | baruun-urt
# Processing Record 46 of Set 3 | russkiy kameshkir
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | the valley
# Processing Record 49 of Set 3 | kavieng
# Processing Record 50 of Set 3 | kodiak
# Processing Record 1 of Set 4 | itarantim
# Processing Record 2 of Set 4 | saint-joseph
# Processing Record 3 of Set 4 | kamaishi
# Processing Record 4 of Set 4 | tautira
# Processing Record 5 of Set 4 | barsovo
# Processing Record 6 of Set 4 | san quintin
# Processing Record 7 of Set 4 | ossora
# Processing Record 8 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 4 | saint-philippe
# Processing Record 10 of Set 4 | kirchberg
# Processing Record 11 of Set 4 | opuwo
# Processing Record 12 of Set 4 | dingle
# Processing Record 13 of Set 4 | russell
# Processing Record 14 of Set 4 | montorio al vomano
# Processing Record 15 of Set 4 | coahuayana
# Processing Record 16 of Set 4 | ochtrup
# Processing Record 17 of Set 4 | eloy
# Processing Record 18 of Set 4 | barrow
# Processing Record 19 of Set 4 | sidi ali
# Processing Record 20 of Set 4 | carnarvon
# Processing Record 21 of Set 4 | one hundred mile house
# City not found. Skipping...
# Processing Record 22 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 4 | lazaro cardenas
# Processing Record 24 of Set 4 | talaya
# Processing Record 25 of Set 4 | meridian
# Processing Record 26 of Set 4 | chikoy
# City not found. Skipping...
# Processing Record 27 of Set 4 | mahebourg
# Processing Record 28 of Set 4 | mallama
# City not found. Skipping...
# Processing Record 29 of Set 4 | padang
# Processing Record 30 of Set 4 | upernavik
# Processing Record 31 of Set 4 | isangel
# Processing Record 32 of Set 4 | freeport
# Processing Record 33 of Set 4 | kapaa
# Processing Record 34 of Set 4 | gardelegen
# Processing Record 35 of Set 4 | tiksi
# Processing Record 36 of Set 4 | lagoa
# Processing Record 37 of Set 4 | portland
# Processing Record 38 of Set 4 | cabedelo
# Processing Record 39 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 4 | esperance
# Processing Record 41 of Set 4 | bambous virieux
# Processing Record 42 of Set 4 | isabela
# Processing Record 43 of Set 4 | saldanha
# Processing Record 44 of Set 4 | lyubashivka
# Processing Record 45 of Set 4 | sao filipe
# Processing Record 46 of Set 4 | merauke
# Processing Record 47 of Set 4 | tabas
# Processing Record 48 of Set 4 | maneadero
# Processing Record 49 of Set 4 | erenhot
# Processing Record 50 of Set 4 | tuatapere
# Processing Record 1 of Set 5 | brae
# Processing Record 2 of Set 5 | bay roberts
# Processing Record 3 of Set 5 | mar del plata
# Processing Record 4 of Set 5 | san andres
# Processing Record 5 of Set 5 | sur
# Processing Record 6 of Set 5 | virginia beach
# Processing Record 7 of Set 5 | bose
# Processing Record 8 of Set 5 | taltal
# Processing Record 9 of Set 5 | saint-georges
# Processing Record 10 of Set 5 | opunake
# Processing Record 11 of Set 5 | baker city
# Processing Record 12 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 13 of Set 5 | ostrovnoy
# Processing Record 14 of Set 5 | soyo
# Processing Record 15 of Set 5 | vila velha
# Processing Record 16 of Set 5 | bengkulu
# Processing Record 17 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 18 of Set 5 | san cristobal
# Processing Record 19 of Set 5 | srednekolymsk
# Processing Record 20 of Set 5 | labuhan
# Processing Record 21 of Set 5 | chokurdakh
# Processing Record 22 of Set 5 | vao
# Processing Record 23 of Set 5 | tavda
# Processing Record 24 of Set 5 | quzhou
# Processing Record 25 of Set 5 | naze
# Processing Record 26 of Set 5 | ojinaga
# Processing Record 27 of Set 5 | ken caryl
# Processing Record 28 of Set 5 | chifeng
# Processing Record 29 of Set 5 | yungay
# Processing Record 30 of Set 5 | faanui
# Processing Record 31 of Set 5 | beboto
# Processing Record 32 of Set 5 | hervey bay
# Processing Record 33 of Set 5 | stornoway
# Processing Record 34 of Set 5 | huallanca
# Processing Record 35 of Set 5 | seddon
# Processing Record 36 of Set 5 | puerto escondido
# Processing Record 37 of Set 5 | richards bay
# Processing Record 38 of Set 5 | vila franca do campo
# Processing Record 39 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 5 | sebrovo
# Processing Record 41 of Set 5 | shepetivka
# Processing Record 42 of Set 5 | carahue
# Processing Record 43 of Set 5 | orsha
# Processing Record 44 of Set 5 | sola
# Processing Record 45 of Set 5 | lavrentiya
# Processing Record 46 of Set 5 | northam
# Processing Record 47 of Set 5 | port hedland
# Processing Record 48 of Set 5 | barkhan
# Processing Record 49 of Set 5 | norman wells
# Processing Record 50 of Set 5 | alofi
# Processing Record 1 of Set 6 | sorland
# Processing Record 2 of Set 6 | tashla
# Processing Record 3 of Set 6 | kpalime
# Processing Record 4 of Set 6 | udachnyy
# Processing Record 5 of Set 6 | noumea
# Processing Record 6 of Set 6 | sinop
# Processing Record 7 of Set 6 | tselinnoye
# Processing Record 8 of Set 6 | wewak
# Processing Record 9 of Set 6 | diffa
# Processing Record 10 of Set 6 | saint-leu
# Processing Record 11 of Set 6 | puerto leguizamo
# Processing Record 12 of Set 6 | gizo
# Processing Record 13 of Set 6 | mehamn
# Processing Record 14 of Set 6 | airai
# Processing Record 15 of Set 6 | saint george
# Processing Record 16 of Set 6 | plettenberg bay
# Processing Record 17 of Set 6 | mayo
# Processing Record 18 of Set 6 | carlos antonio lopez
# Processing Record 19 of Set 6 | margate
# Processing Record 20 of Set 6 | east london
# Processing Record 21 of Set 6 | gwadar
# Processing Record 22 of Set 6 | deputatskiy
# Processing Record 23 of Set 6 | poum
# Processing Record 24 of Set 6 | chulym
# Processing Record 25 of Set 6 | batagay-alyta
# Processing Record 26 of Set 6 | skjervoy
# Processing Record 27 of Set 6 | ninotsminda
# Processing Record 28 of Set 6 | bako
# Processing Record 29 of Set 6 | leshukonskoye
# Processing Record 30 of Set 6 | caravelas
# Processing Record 31 of Set 6 | oksfjord
# Processing Record 32 of Set 6 | hailey
# Processing Record 33 of Set 6 | rio gallegos
# Processing Record 34 of Set 6 | bowen
# Processing Record 35 of Set 6 | kuzhener
# Processing Record 36 of Set 6 | maniitsoq
# Processing Record 37 of Set 6 | kargapolye
# City not found. Skipping...
# Processing Record 38 of Set 6 | kahului
# Processing Record 39 of Set 6 | krasnyy chikoy
# Processing Record 40 of Set 6 | broome
# Processing Record 41 of Set 6 | kjollefjord
# Processing Record 42 of Set 6 | seymchan
# Processing Record 43 of Set 6 | rio grande
# Processing Record 44 of Set 6 | mikkeli
# Processing Record 45 of Set 6 | broken hill
# Processing Record 46 of Set 6 | lasa
# Processing Record 47 of Set 6 | aloleng
# Processing Record 48 of Set 6 | umm lajj
# Processing Record 49 of Set 6 | simpang
# Processing Record 50 of Set 6 | laguna
# Processing Record 1 of Set 7 | tinaquillo
# Processing Record 2 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 7 | selma
# Processing Record 4 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 7 | pacific grove
# Processing Record 6 of Set 7 | terney
# Processing Record 7 of Set 7 | husavik
# Processing Record 8 of Set 7 | vyartsilya
# Processing Record 9 of Set 7 | leningradskiy
# Processing Record 10 of Set 7 | malinovskiy
# Processing Record 11 of Set 7 | zapolyarnyy
# Processing Record 12 of Set 7 | cabo san lucas
# Processing Record 13 of Set 7 | lima
# Processing Record 14 of Set 7 | hialeah gardens
# Processing Record 15 of Set 7 | cockburn town
# Processing Record 16 of Set 7 | sharan
# Processing Record 17 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 18 of Set 7 | bahia blanca
# Processing Record 19 of Set 7 | maarianhamina
# Processing Record 20 of Set 7 | redding
# Processing Record 21 of Set 7 | hun
# Processing Record 22 of Set 7 | morro bay
# Processing Record 23 of Set 7 | khlevnoye
# Processing Record 24 of Set 7 | ulaangom
# Processing Record 25 of Set 7 | mattru
# Processing Record 26 of Set 7 | omboue
# Processing Record 27 of Set 7 | mahendranagar
# Processing Record 28 of Set 7 | patiya
# Processing Record 29 of Set 7 | sawakin
# Processing Record 30 of Set 7 | aklavik
# Processing Record 31 of Set 7 | maldonado
# Processing Record 32 of Set 7 | korla
# Processing Record 33 of Set 7 | kandana
# Processing Record 34 of Set 7 | harer
# Processing Record 35 of Set 7 | mezen
# Processing Record 36 of Set 7 | male
# Processing Record 37 of Set 7 | tondano
# Processing Record 38 of Set 7 | awbari
# Processing Record 39 of Set 7 | takoradi
# Processing Record 40 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 7 | hay river
# Processing Record 42 of Set 7 | inuvik
# Processing Record 43 of Set 7 | jati
# Processing Record 44 of Set 7 | boa vista
# Processing Record 45 of Set 7 | tikhvin
# Processing Record 46 of Set 7 | cooma
# Processing Record 47 of Set 7 | lata
# Processing Record 48 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 49 of Set 7 | pagudpud
# Processing Record 50 of Set 7 | mumford
# Processing Record 1 of Set 8 | sayat
# Processing Record 2 of Set 8 | salalah
# Processing Record 3 of Set 8 | krasnoselkup
# Processing Record 4 of Set 8 | kholtoson
# Processing Record 5 of Set 8 | suntar
# Processing Record 6 of Set 8 | la ronge
# Processing Record 7 of Set 8 | raga
# Processing Record 8 of Set 8 | buchanan
# Processing Record 9 of Set 8 | bacolod
# Processing Record 10 of Set 8 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 11 of Set 8 | floro
# Processing Record 12 of Set 8 | pisco
# Processing Record 13 of Set 8 | birin
# Processing Record 14 of Set 8 | siderno
# Processing Record 15 of Set 8 | lishui
# Processing Record 16 of Set 8 | kizema
# Processing Record 17 of Set 8 | dikson
# Processing Record 18 of Set 8 | pyapon
# Processing Record 19 of Set 8 | kautokeino
# Processing Record 20 of Set 8 | yangjiang
# Processing Record 21 of Set 8 | pangkalanbuun
# Processing Record 22 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 8 | sansai
# City not found. Skipping...
# Processing Record 24 of Set 8 | itoman
# Processing Record 25 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 8 | hambantota
# Processing Record 27 of Set 8 | chara
# Processing Record 28 of Set 8 | boyolangu
# Processing Record 29 of Set 8 | prince rupert
# Processing Record 30 of Set 8 | mount gambier
# Processing Record 31 of Set 8 | garzon
# Processing Record 32 of Set 8 | ponta delgada
# Processing Record 33 of Set 8 | payo
# Processing Record 34 of Set 8 | kribi
# Processing Record 35 of Set 8 | tombouctou
# Processing Record 36 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 8 | reconquista
# Processing Record 38 of Set 8 | wukari
# Processing Record 39 of Set 8 | pangnirtung
# Processing Record 40 of Set 8 | nicoya
# Processing Record 41 of Set 8 | rosehearty
# Processing Record 42 of Set 8 | lovozero
# Processing Record 43 of Set 8 | xining
# Processing Record 44 of Set 8 | mulbagal
# Processing Record 45 of Set 8 | tacuarembo
# Processing Record 46 of Set 8 | aranda de duero
# Processing Record 47 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 8 | ilulissat
# Processing Record 49 of Set 8 | songjianghe
# Processing Record 50 of Set 8 | honiara
# Processing Record 1 of Set 9 | balkhash
# Processing Record 2 of Set 9 | egvekinot
# Processing Record 3 of Set 9 | zaysan
# Processing Record 4 of Set 9 | leh
# Processing Record 5 of Set 9 | changqing
# Processing Record 6 of Set 9 | khandyga
# Processing Record 7 of Set 9 | durban
# Processing Record 8 of Set 9 | pozo colorado
# Processing Record 9 of Set 9 | borisovka
# Processing Record 10 of Set 9 | bandundu
# Processing Record 11 of Set 9 | souillac
# Processing Record 12 of Set 9 | ustyuzhna
# Processing Record 13 of Set 9 | fonte boa
# Processing Record 14 of Set 9 | hualmay
# Processing Record 15 of Set 9 | sena madureira
# Processing Record 16 of Set 9 | alexandria
# Processing Record 17 of Set 9 | yar-sale
# Processing Record 18 of Set 9 | kamphaeng phet
# Processing Record 19 of Set 9 | menongue
# Processing Record 20 of Set 9 | shimminato
# Processing Record 21 of Set 9 | qasigiannguit
# Processing Record 22 of Set 9 | ravar
# Processing Record 23 of Set 9 | corinto
# Processing Record 24 of Set 9 | ondjiva
# Processing Record 25 of Set 9 | baykit
# Processing Record 26 of Set 9 | ambovombe
# Processing Record 27 of Set 9 | lompoc
# Processing Record 28 of Set 9 | sitka
# Processing Record 29 of Set 9 | kutum
# Processing Record 30 of Set 9 | klaksvik
# Processing Record 31 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 32 of Set 9 | grindavik
# Processing Record 33 of Set 9 | jiwani
# Processing Record 34 of Set 9 | weinan
# Processing Record 35 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 36 of Set 9 | port augusta
# Processing Record 37 of Set 9 | estelle
# Processing Record 38 of Set 9 | braco do norte
# Processing Record 39 of Set 9 | lodja
# Processing Record 40 of Set 9 | san rafael del sur
# Processing Record 41 of Set 9 | lethem
# Processing Record 42 of Set 9 | tevriz
# Processing Record 43 of Set 9 | kruisfontein
# Processing Record 44 of Set 9 | dondo
# Processing Record 45 of Set 9 | halifax
# Processing Record 46 of Set 9 | khandagayty
# Processing Record 47 of Set 9 | luba
# Processing Record 48 of Set 9 | sao caetano de odivelas
# Processing Record 49 of Set 9 | shihezi
# Processing Record 50 of Set 9 | faribault
# Processing Record 1 of Set 10 | kysyl-syr
# Processing Record 2 of Set 10 | big rapids
# Processing Record 3 of Set 10 | massaguet
# Processing Record 4 of Set 10 | tigil
# Processing Record 5 of Set 10 | yiyang
# Processing Record 6 of Set 10 | mildura
# Processing Record 7 of Set 10 | mirpur bathoro
# City not found. Skipping...
# Processing Record 8 of Set 10 | dzhebariki-khaya
# Processing Record 9 of Set 10 | sovetskiy
# Processing Record 10 of Set 10 | upington
# Processing Record 11 of Set 10 | burevestnik
# Processing Record 12 of Set 10 | lewisporte
# Processing Record 13 of Set 10 | slave lake
# Processing Record 14 of Set 10 | karratha
# Processing Record 15 of Set 10 | gresham
# Processing Record 16 of Set 10 | kosa
# Processing Record 17 of Set 10 | berlevag
# Processing Record 18 of Set 10 | pizarro
# Processing Record 19 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 10 | magrath
# Processing Record 21 of Set 10 | velyka mykhaylivka
# Processing Record 22 of Set 10 | kalmunai
# Processing Record 23 of Set 10 | halmstad
# Processing Record 24 of Set 10 | anadyr
# Processing Record 25 of Set 10 | eyl
# Processing Record 26 of Set 10 | dudinka
# Processing Record 27 of Set 10 | auki
# Processing Record 28 of Set 10 | zharkent
# Processing Record 29 of Set 10 | vardo
# Processing Record 30 of Set 10 | springbok
# Processing Record 31 of Set 10 | longyearbyen
# Processing Record 32 of Set 10 | shingu
# Processing Record 33 of Set 10 | gurupa
# Processing Record 34 of Set 10 | itapipoca
# Processing Record 35 of Set 10 | porto novo
# Processing Record 36 of Set 10 | cap malheureux
# Processing Record 37 of Set 10 | villanueva de la serena
# Processing Record 38 of Set 10 | chabahar
# Processing Record 39 of Set 10 | porto walter
# Processing Record 40 of Set 10 | cutro
# Processing Record 41 of Set 10 | tyup
# Processing Record 42 of Set 10 | dubbo
# Processing Record 43 of Set 10 | salinopolis
# Processing Record 44 of Set 10 | lydenburg
# Processing Record 45 of Set 10 | yazd
# Processing Record 46 of Set 10 | yuganets
# Processing Record 47 of Set 10 | kommunisticheskiy
# Processing Record 48 of Set 10 | autazes
# Processing Record 49 of Set 10 | emerald
# Processing Record 50 of Set 10 | manjeri
# Processing Record 1 of Set 11 | kiunga
# Processing Record 2 of Set 11 | wahiawa
# Processing Record 3 of Set 11 | nelidovo
# Processing Record 4 of Set 11 | haines junction
# Processing Record 5 of Set 11 | alice springs
# Processing Record 6 of Set 11 | melito di porto salvo
# Processing Record 7 of Set 11 | shumskiy
# Processing Record 8 of Set 11 | byron bay
# Processing Record 9 of Set 11 | xai-xai
# Processing Record 10 of Set 11 | avera
# Processing Record 11 of Set 11 | qabis
# City not found. Skipping...
# Processing Record 12 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 11 | ancud
# Processing Record 14 of Set 11 | lalpur
# Processing Record 15 of Set 11 | namatanai
# Processing Record 16 of Set 11 | alma
# Processing Record 17 of Set 11 | dunedin
# Processing Record 18 of Set 11 | manta
# Processing Record 19 of Set 11 | fallon
# Processing Record 20 of Set 11 | quelimane
# Processing Record 21 of Set 11 | puerto ayacucho
# Processing Record 22 of Set 11 | half moon bay
# Processing Record 23 of Set 11 | ilek
# Processing Record 24 of Set 11 | kyra
# Processing Record 25 of Set 11 | isla vista
# Processing Record 26 of Set 11 | saurimo
# Processing Record 27 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 11 | tiarei
# Processing Record 29 of Set 11 | narsaq
# Processing Record 30 of Set 11 | lorengau
# Processing Record 31 of Set 11 | rostock
# Processing Record 32 of Set 11 | puerto narino
# Processing Record 33 of Set 11 | predejane
# Processing Record 34 of Set 11 | waingapu
# Processing Record 35 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 11 | adrar
# Processing Record 37 of Set 11 | yeniseysk
# Processing Record 38 of Set 11 | clyde river
# Processing Record 39 of Set 11 | kirando
# Processing Record 40 of Set 11 | borovskoy
# Processing Record 41 of Set 11 | terrasini
# Processing Record 42 of Set 11 | snezhnogorsk
# Processing Record 43 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 11 | eston
# Processing Record 45 of Set 11 | dromolaxia
# Processing Record 46 of Set 11 | floresti
# Processing Record 47 of Set 11 | nacogdoches
# Processing Record 48 of Set 11 | makakilo city
# Processing Record 49 of Set 11 | kilrush
# Processing Record 50 of Set 11 | bambanglipuro
# Processing Record 1 of Set 12 | bud
# Processing Record 2 of Set 12 | kirkenaer
# Processing Record 3 of Set 12 | tessalit
# Processing Record 4 of Set 12 | tena
# Processing Record 5 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 12 | kropotkin
# Processing Record 7 of Set 12 | mecca
# Processing Record 8 of Set 12 | uarini
# Processing Record 9 of Set 12 | nome
# Processing Record 10 of Set 12 | hargeysa
# Processing Record 11 of Set 12 | timra
# Processing Record 12 of Set 12 | bayonet point
# Processing Record 13 of Set 12 | roald
# Processing Record 14 of Set 12 | samana
# Processing Record 15 of Set 12 | kingsport
# Processing Record 16 of Set 12 | thanh hoa
# Processing Record 17 of Set 12 | finspang
# Processing Record 18 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 12 | caracuaro
# Processing Record 20 of Set 12 | sao gabriel
# Processing Record 21 of Set 12 | maumee
# Processing Record 22 of Set 12 | necochea
# Processing Record 23 of Set 12 | mezhdurechenskiy
# Processing Record 24 of Set 12 | biak
# Processing Record 25 of Set 12 | kerouane
# Processing Record 26 of Set 12 | merritt
# Processing Record 27 of Set 12 | kvitok
# Processing Record 28 of Set 12 | jasper
# Processing Record 29 of Set 12 | sokoni
# Processing Record 30 of Set 12 | teguise
# Processing Record 31 of Set 12 | hofn
# Processing Record 32 of Set 12 | yarada
# Processing Record 33 of Set 12 | gat
# Processing Record 34 of Set 12 | port hardy
# Processing Record 35 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 36 of Set 12 | progreso
# Processing Record 37 of Set 12 | comodoro rivadavia
# Processing Record 38 of Set 12 | port blair
# Processing Record 39 of Set 12 | rocha
# Processing Record 40 of Set 12 | mogadishu
# Processing Record 41 of Set 12 | port-gentil
# Processing Record 42 of Set 12 | kantunilkin
# Processing Record 43 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 44 of Set 12 | najran
# Processing Record 45 of Set 12 | wajid
# Processing Record 46 of Set 12 | natchez
# Processing Record 47 of Set 12 | sesheke
# Processing Record 48 of Set 12 | barreirinhas
# Processing Record 49 of Set 12 | turukhansk
# Processing Record 50 of Set 12 | polyarnyy
# Processing Record 1 of Set 13 | ouahigouya
# Processing Record 2 of Set 13 | beringovskiy
# Processing Record 3 of Set 13 | bahia honda
# Processing Record 4 of Set 13 | seguela
# Processing Record 5 of Set 13 | camacha
# Processing Record 6 of Set 13 | havoysund
# Processing Record 7 of Set 13 | redmond
# Processing Record 8 of Set 13 | maxixe
# Processing Record 9 of Set 13 | les cayes
# Processing Record 10 of Set 13 | poltavka
# Processing Record 11 of Set 13 | bujumbura
# Processing Record 12 of Set 13 | chute-aux-outardes
# Processing Record 13 of Set 13 | netivot
# Processing Record 14 of Set 13 | tabou
# Processing Record 15 of Set 13 | ballina
# Processing Record 16 of Set 13 | sistranda
# Processing Record 17 of Set 13 | nurmijarvi
# Processing Record 18 of Set 13 | marechal floriano
# Processing Record 19 of Set 13 | landeck
# Processing Record 20 of Set 13 | high level
# Processing Record 21 of Set 13 | hornepayne
# Processing Record 22 of Set 13 | marzuq
# Processing Record 23 of Set 13 | gerede
# Processing Record 24 of Set 13 | amarante do maranhao
# Processing Record 25 of Set 13 | mackenzie
# Processing Record 26 of Set 13 | lokot
# Processing Record 27 of Set 13 | jiazi
# Processing Record 28 of Set 13 | bayburt
# Processing Record 29 of Set 13 | mareeba
# Processing Record 30 of Set 13 | yelizovo
# Processing Record 31 of Set 13 | haapiti
# Processing Record 32 of Set 13 | alginet
# Processing Record 33 of Set 13 | praya
# Processing Record 34 of Set 13 | ugoofaaru
# Processing Record 35 of Set 13 | djibo
# Processing Record 36 of Set 13 | asau
# Processing Record 37 of Set 13 | fartanesti
# City not found. Skipping...
# Processing Record 38 of Set 13 | ordzhonikidzevskiy
# Processing Record 39 of Set 13 | dombarovskiy
# Processing Record 40 of Set 13 | sebinkarahisar
# Processing Record 41 of Set 13 | itarema
# Processing Record 42 of Set 13 | dalvik
# Processing Record 43 of Set 13 | betafo
# Processing Record 44 of Set 13 | magistralnyy
# Processing Record 45 of Set 13 | altea
# Processing Record 46 of Set 13 | bathsheba
# Processing Record 47 of Set 13 | svetlogorsk
# Processing Record 48 of Set 13 | tsuruoka
# Processing Record 49 of Set 13 | wonthaggi
# Processing Record 50 of Set 13 | wairoa
# Processing Record 1 of Set 14 | sertania
# Processing Record 2 of Set 14 | korem
# Processing Record 3 of Set 14 | mahibadhoo
# Processing Record 4 of Set 14 | nuuk
# Processing Record 5 of Set 14 | coquimbo
# Processing Record 6 of Set 14 | akyab
# Processing Record 7 of Set 14 | waitati
# Processing Record 8 of Set 14 | orlik
# Processing Record 9 of Set 14 | kaka
# Processing Record 10 of Set 14 | agadez
# Processing Record 11 of Set 14 | jalu
# Processing Record 12 of Set 14 | mabaruma
# Processing Record 13 of Set 14 | mackay
# Processing Record 14 of Set 14 | yushu
# Processing Record 15 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 14 | candolim
# Processing Record 17 of Set 14 | crawfordsville
# Processing Record 18 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 14 | pangai
# Processing Record 20 of Set 14 | plover
# Processing Record 21 of Set 14 | jamame
# Processing Record 22 of Set 14 | wajir
# Processing Record 23 of Set 14 | westerland
# Processing Record 24 of Set 14 | ayan
# Processing Record 25 of Set 14 | yumen
# Processing Record 26 of Set 14 | teguldet
# Processing Record 27 of Set 14 | southbridge
# Processing Record 28 of Set 14 | nanyang
# Processing Record 29 of Set 14 | nanortalik
# Processing Record 30 of Set 14 | morros
# Processing Record 31 of Set 14 | coron
# Processing Record 32 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 14 | brandfort
# Processing Record 34 of Set 14 | penukonda
# Processing Record 35 of Set 14 | berdigestyakh
# Processing Record 36 of Set 14 | nisia floresta
# Processing Record 37 of Set 14 | samarai
# Processing Record 38 of Set 14 | escuinapa
# Processing Record 39 of Set 14 | athens
# Processing Record 40 of Set 14 | maun
# Processing Record 41 of Set 14 | bongandanga
# Processing Record 42 of Set 14 | bosaso
# Processing Record 43 of Set 14 | umtata
# Processing Record 44 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 46 of Set 14 | basyanovskiy
# City not found. Skipping...
# Processing Record 47 of Set 14 | sobolevo
# Processing Record 48 of Set 14 | temiscaming
# Processing Record 49 of Set 14 | tabuk
# Processing Record 50 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 2 of Set 15 | medicine hat
# Processing Record 3 of Set 15 | syumsi
# Processing Record 4 of Set 15 | puerto colombia
# Processing Record 5 of Set 15 | havelock
# Processing Record 6 of Set 15 | salta
# Processing Record 7 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 8 of Set 15 | hingoli
# Processing Record 9 of Set 15 | canon city
# Processing Record 10 of Set 15 | road town
# Processing Record 11 of Set 15 | cape canaveral
# Processing Record 12 of Set 15 | altay
# Processing Record 13 of Set 15 | magalia
# Processing Record 14 of Set 15 | stantsionno-oyashinskiy
# Processing Record 15 of Set 15 | torit
# Processing Record 16 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 17 of Set 15 | hanyang
# Processing Record 18 of Set 15 | lincoln
# Processing Record 19 of Set 15 | okhotsk
# Processing Record 20 of Set 15 | chauk
# Processing Record 21 of Set 15 | belyy yar
# Processing Record 22 of Set 15 | cozumel
# Processing Record 23 of Set 15 | assesse
# Processing Record 24 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 15 | ust-nera
# Processing Record 26 of Set 15 | lewisville
# Processing Record 27 of Set 15 | fort nelson
# Processing Record 28 of Set 15 | walvis bay
# Processing Record 29 of Set 15 | san jose
# Processing Record 30 of Set 15 | gallup
# Processing Record 31 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 15 | ust-tsilma
# Processing Record 33 of Set 15 | singkawang
# Processing Record 34 of Set 15 | fruitville
# Processing Record 35 of Set 15 | henderson
# Processing Record 36 of Set 15 | brahmapuri
# City not found. Skipping...
# Processing Record 37 of Set 15 | valparaiso
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 675

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bethel  41.3712  -73.4140     54.48        73          90
# 1       Rikitea -23.1203 -134.9692     75.56        76          99
# 2         Amapa   1.0000  -52.0000     85.19        55         100
# 3       Ushuaia -54.8000  -68.3000     51.42        53          40
# 4  Marsa Matruh  31.3525   27.2453     72.55        75         100
#
#    Wind Speed Current Description Country
# 0        3.00     overcast clouds      US
# 1       18.30     overcast clouds      PF
# 2        3.02     overcast clouds      BR
# 3       29.93    scattered clouds      AR
# 4        6.20     overcast clouds      EG

# %%
new_column_order = ["City", "Country", "Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bethel      US  41.3712  -73.4140     54.48        73          90
# 1         Rikitea      PF -23.1203 -134.9692     75.56        76          99
# 2           Amapa      BR   1.0000  -52.0000     85.19        55         100
# 3         Ushuaia      AR -54.8000  -68.3000     51.42        53          40
# 4    Marsa Matruh      EG  31.3525   27.2453     72.55        75         100
# 5          Hobart      AU -42.8794  147.3294     44.46        70          90
# 6    Port Lincoln      AU -34.7333  135.8667     51.51        62          56
# 7       Busselton      AU -33.6500  115.3333     46.04        83          17
# 8  Severo-Kurilsk      RU  50.6789  156.1250     43.02        98         100
# 9         Mataura      NZ -46.1927  168.8643     51.44        90          67
#
#    Wind Speed Current Description
# 0        3.00     overcast clouds
# 1       18.30     overcast clouds
# 2        3.02     overcast clouds
# 3       29.93    scattered clouds
# 4        6.20     overcast clouds
# 5       14.97     overcast clouds
# 6        7.38       broken clouds
# 7        8.39          few clouds
# 8        6.55     overcast clouds
# 9        4.03       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
